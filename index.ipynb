# %% [markdown]
# # SQL Interview Questions  - Quiz
#
#
# ## Introduction
#
# This quiz contains questions on topics you can expect to see in an interview pertaining to SQL and Relational Databases. Some of them are multiple choice, while some are short answer. For these short answer questions, double click on the Jupyter Notebook and type your answer below the line.
#
# ## Question 1
#
# What are the 4 main datatypes in SQLite3? Can we use other common types from other kinds of SQL?
#
# Type your answer below this line:
# _______________________________________________________________________________________________________________________________
# TEXT
# INTEGER
# REAL
# BLOB
#
# ## Question 2
#
# Explain the relationship between **Primary Keys** and **Foreign Keys**.
#
# Type your answer below this line:
# _______________________________________________________________________________________________________________________________
#
# A primary key is a key that uniquely indetifies a row. Foreign keys are not the primary key for that particular table but for another table.
#
#
#
# ## Question 3
#
# Explain the different types of relationships entities can have in a SQL database.
#
# Type your answer below this line:
# _______________________________________________________________________________________________________________________________
# You can have One-to-Many or Many-to-Many relationships. One-to-Many combines multiple datafields into 1 field. Many-to-Many combines multiple fields into other multiple fields.
#
#
# ## Question 4
#
# Explain the various types of JOINs possible with SQL.
#
# Type your answer below this line:
# _______________________________________________________________________________________________________________________________
# There is also INNER JOINS which only pulls if a match from both tables.
# There is RIGHT JOIN, where the keyword returns all records from the right table.
# There is FULL OUTTER JOIN, where the keyword joins all tables.
# There is LEFT JOIN, where the keyword returns all records from the left table.
#
#
# ## Question 5
#
# Explain the relationship between Aggregate functions and GROUP BY statements.
#
# Type your answer below this line:
# _______________________________________________________________________________________________________________________________
# GROUP BY Clause groups records into summary rows and returns on record for each group, in one more more columns. Typically these involve an aggregate function like COUNT or AVE.
#
#
# ## Question 6
#
# What role do Associative Entities play (JOIN Tables) in many-to-many JOINs?
#
#
# Type your answer below this line:
# _______________________________________________________________________________________________________________________________
# Associative Enities can end up creating sever load on databases and causing slow execution times for other users on the system. Also the data becomes massive.
#
#
# ## Summary
#
# In this lesson, we practiced answering open-ended interview questions for SQL and Relational Databases.
